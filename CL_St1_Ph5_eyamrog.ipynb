# %% [markdown]
# <center>
# <img src="https://laelgelcpublic.s3.sa-east-1.amazonaws.com/lael_50_years_narrow_white.png.no_years.400px_96dpi.png" width="300" alt="LAEL 50 years logo">
# <h3>APPLIED LINGUISTICS GRADUATE PROGRAMME (LAEL)</h3>
# </center>
# <hr>

# %% [markdown]
# # Corpus Linguistics - Study 1 - Phase 5 - eyamrog

# %% [markdown]
# The aim of this phase is extending the data set to the paragraph level by including the `section` and `paragraph` categories.

# %% [markdown]
# ## Required Python packages

# %% [markdown]
# - beautifulsoup4
# - PyMuPDF
# - lxml
# - pandas
# - requests

# %% [markdown]
# ## Importing the required libraries

# %%
import requests
from bs4 import BeautifulSoup
import fitz # PyMuPDF
import re
import pandas as pd
import os
import sys
import logging
from tqdm import tqdm
import matplotlib.pyplot as plt
import json

# %% [markdown]
# ## Defining input variables

# %%
input_directory = 'cl_st1_ph4_eyamrog'
output_directory = 'cl_st1_ph5_eyamrog'

# %% [markdown]
# ## Creating output directory

# %%
# Check if the output directory already exists. If it does, do nothing. If it doesn't exist, create it.
if os.path.exists(output_directory):
    print('Output directory already exists.')
else:
    try:
        os.makedirs(output_directory)
        print('Output directory successfully created.')
    except OSError as e:
        print('Failed to create the directory:', e)
        sys.exit(1)
# Out:
# Output directory successfully created.

# %% [markdown]
# ## Extending the data set to the paragraph level

# %% [markdown]
# ### Importing the data into a DataFrame

# %%
df_scielo_preprint_preChatGPT_en = pd.read_json(f'{input_directory}/scielo_chatgpt_erpp_pp.jsonl', lines=True)

# %%
df_scielo_preprint_preChatGPT_en.dtypes
# Out:
# Title                    object
# URL                      object
# Authors                  object
# Published                object
# PDF Language             object
# PDF URL                  object
# Submitted                 int64
# Posted                    int64
# Text                     object
# Text ID                  object
# Area of Knowledge        object
# Text Paragraphs          object
# Text Paragraphs Count     int64
# Text ChatGPT             object
# dtype: object

# %%
df_scielo_preprint_preChatGPT_en['Submitted'] = pd.to_datetime(df_scielo_preprint_preChatGPT_en['Submitted'], unit='ms')
df_scielo_preprint_preChatGPT_en['Posted'] = pd.to_datetime(df_scielo_preprint_preChatGPT_en['Posted'], unit='ms')

# %%
df_scielo_preprint_preChatGPT_en
# Out:
#                                                  Title  \
# 0    (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1    Assembling the perfect bacterial genome using ...
# 2    ON METHODOLOGY AND METHODS FOR ANALYSING CLASS...
# 3    MOBILIZING LINGUISTIC AND SEMIOTIC RESOURCES, ...
# 4    PORTUGUESE AO PÉ DO BERIMBAU: ON CAPOEIRA AS A...
# ..                                                 ...
# 311  Challenges in the fight against the COVID-19 p...
# 312  Information about the new coronavirus disease ...
# 313  ACE2 diversity in placental mammals reveals th...
# 314  Coronavirus 2: Analysis of Regularity of Compl...
# 315  COVID-19 in Brazil: advantages of a socialized...
#
#                                                    URL  \
# 0    https://preprints.scielo.org/index.php/scielo/...
# 1    https://preprints.scielo.org/index.php/scielo/...
# 2    https://preprints.scielo.org/index.php/scielo/...
# 3    https://preprints.scielo.org/index.php/scielo/...
# 4    https://preprints.scielo.org/index.php/scielo/...
# ..                                                 ...
# 311  https://preprints.scielo.org/index.php/scielo/...
# 312  https://preprints.scielo.org/index.php/scielo/...
# 313  https://preprints.scielo.org/index.php/scielo/...
# 314  https://preprints.scielo.org/index.php/scielo/...
# 315  https://preprints.scielo.org/index.php/scielo/...
#
#                                                Authors  \
# 0      Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 1        Ryan R. Wick, Louise M. Judd, Kathryn E. Holt
# 2                              Leonardo Goncalves Lago
# 3                 Estêvão Cabral, Marylin Martin-Jones
# 4                        Mike Baynham, Jolana Hanusova
# ..                                                 ...
# 311               Eduardo Alexandrino Servolo Medeiros
# 312            Claudio Márcio Amaral de Oliveira  Lima
# 313  Bibiana Sampaio de Oliveira Fam, Pedro Vargas-...
# 314                                 Yuri Morales-López
# 315  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
#
#                                     Published PDF Language  \
# 0    Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 1    Submitted 11/11/2022 - Posted 11/11/2022          PDF
# 2    Submitted 11/10/2022 - Posted 11/16/2022          PDF
# 3    Submitted 11/07/2022 - Posted 11/07/2022          PDF
# 4    Submitted 11/04/2022 - Posted 11/04/2022          PDF
# ..                                        ...          ...
# 311  Submitted 04/15/2020 - Posted 04/15/2020          PDF
# 312  Submitted 04/13/2020 - Posted 04/13/2020          PDF
# 313  Submitted 04/11/2020 - Posted 04/28/2020          PDF
# 314  Submitted 04/10/2020 - Posted 06/04/2020          PDF
# 315  Submitted 04/06/2020 - Posted 04/08/2020          PDF
#
#                                                PDF URL  Submitted     Posted  \
# 0    https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-23
# 1    https://preprints.scielo.org/index.php/scielo/... 2022-11-11 2022-11-11
# 2    https://preprints.scielo.org/index.php/scielo/... 2022-11-10 2022-11-16
# 3    https://preprints.scielo.org/index.php/scielo/... 2022-11-07 2022-11-07
# 4    https://preprints.scielo.org/index.php/scielo/... 2022-11-04 2022-11-04
# ..                                                 ...        ...        ...
# 311  https://preprints.scielo.org/index.php/scielo/... 2020-04-15 2020-04-15
# 312  https://preprints.scielo.org/index.php/scielo/... 2020-04-13 2020-04-13
# 313  https://preprints.scielo.org/index.php/scielo/... 2020-04-11 2020-04-28
# 314  https://preprints.scielo.org/index.php/scielo/... 2020-04-10 2020-06-04
# 315  https://preprints.scielo.org/index.php/scielo/... 2020-04-06 2020-04-08
#
#                                                   Text  Text ID  \
# 0    Publication status: Preprint has been publishe...  t000000
# 1    Publication status: Preprint has been publishe...  t000001
# 2    Publication status: Preprint has been publishe...  t000002
# 3    Publication status: Preprint has been submitte...  t000003
# 4    Publication status: Preprint has been submitte...  t000004
# ..                                                 ...      ...
# 311  *Corresponding author. E-mail: edubalaccih@gma...  t000311
# 312  V\nRadiol Bras. 2020 Mar/Abr;53(2):V–VI\n0100-...  t000312
# 313  Status: Preprint has been published in a journ...  t000313
# 314  Publication status: Preprint has been publishe...  t000314
# 315    1/6\nRevista da Sociedade Brasileira de Medi...  t000315
#
#                    Area of Knowledge  \
# 0                Biological Sciences
# 1                Biological Sciences
# 2            Applied Social Sciences
# 3    Linguistic, literature and arts
# 4    Linguistic, literature and arts
# ..                               ...
# 311                  Health Sciences
# 312                  Health Sciences
# 313              Biological Sciences
# 314              Biological Sciences
# 315                  Health Sciences
#
#                                        Text Paragraphs  Text Paragraphs Count  \
# 0    (Fern flora of Viçosa, Minas Gerais State, Bra...                     29
# 1    A perfect bacterial genome assembly is one whe...                     31
# 2    This article presents a theoretical work whose...                     65
# 3    This paper is based on research of a socioling...                     58
# 4    From its historical origins as a resistant and...                    123
# ..                                                 ...                    ...
# 311  We are living the most important pandemic in r...                      9
# 312  Coronavirus is a zoonotic virus, an RNA virus ...                      9
# 313  The recent emergence of SARS-CoV-2 is responsi...                     35
# 314  This paper shows a technique for the detection...                     15
# 315  The outbreak of new coronavirus disease 2019 (...                     21
#
#                                           Text ChatGPT
# 0    In this research article focusing on the fern ...
# 1    A flawless bacterial genome assembly is charac...
# 2    This article presents a theoretical work with ...
# 3    This paper presents a sociolinguistic and ethn...
# 4    Originating as a defiant and violently suppres...
# ..                                                 ...
# 311  The ongoing global pandemic, triggered by the ...
# 312  The coronavirus is a zoonotic RNA virus belong...
# 313  The recent emergence of SARS-CoV-2 has led to ...
# 314  This paper presents a technique for detecting ...
# 315  The emergence of the novel coronavirus disease...
#
# [316 rows x 14 columns]

# %% [markdown]
# ### Checking the maximum number of paragraphs per text

# %%
df_scielo_preprint_preChatGPT_en['Text Paragraphs Count'].max()
# Out:
# 163

# %% [markdown]
# ### Obtaining the list of Text IDs

# %%
text_id_list = df_scielo_preprint_preChatGPT_en['Text ID'].tolist()

# %%
with open(f"{output_directory}/text_ids.txt", 'w', encoding='utf8', newline='\n') as file:
    for text_id in text_id_list:
        file.write(f'{text_id}\n')

# %% [markdown]
# ### Testing with a data subset

# %% [markdown]
# #### Creating the data subset

# %%
#df_test = df_scielo_preprint_preChatGPT_en.head(4) # Alternative command
df_test = df_scielo_preprint_preChatGPT_en.iloc[:4]
df_test = df_test.reset_index(drop=True)

# %%
df_test
# Out:
#                                                Title  \
# 0  (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1  Assembling the perfect bacterial genome using ...
# 2  ON METHODOLOGY AND METHODS FOR ANALYSING CLASS...
# 3  MOBILIZING LINGUISTIC AND SEMIOTIC RESOURCES, ...
#
#                                                  URL  \
# 0  https://preprints.scielo.org/index.php/scielo/...
# 1  https://preprints.scielo.org/index.php/scielo/...
# 2  https://preprints.scielo.org/index.php/scielo/...
# 3  https://preprints.scielo.org/index.php/scielo/...
#
#                                            Authors  \
# 0  Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 1    Ryan R. Wick, Louise M. Judd, Kathryn E. Holt
# 2                          Leonardo Goncalves Lago
# 3             Estêvão Cabral, Marylin Martin-Jones
#
#                                   Published PDF Language  \
# 0  Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 1  Submitted 11/11/2022 - Posted 11/11/2022          PDF
# 2  Submitted 11/10/2022 - Posted 11/16/2022          PDF
# 3  Submitted 11/07/2022 - Posted 11/07/2022          PDF
#
#                                              PDF URL  Submitted     Posted  \
# 0  https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-23
# 1  https://preprints.scielo.org/index.php/scielo/... 2022-11-11 2022-11-11
# 2  https://preprints.scielo.org/index.php/scielo/... 2022-11-10 2022-11-16
# 3  https://preprints.scielo.org/index.php/scielo/... 2022-11-07 2022-11-07
#
#                                                 Text  Text ID  \
# 0  Publication status: Preprint has been publishe...  t000000
# 1  Publication status: Preprint has been publishe...  t000001
# 2  Publication status: Preprint has been publishe...  t000002
# 3  Publication status: Preprint has been submitte...  t000003
#
#                  Area of Knowledge  \
# 0              Biological Sciences
# 1              Biological Sciences
# 2          Applied Social Sciences
# 3  Linguistic, literature and arts
#
#                                      Text Paragraphs  Text Paragraphs Count  \
# 0  (Fern flora of Viçosa, Minas Gerais State, Bra...                     29
# 1  A perfect bacterial genome assembly is one whe...                     31
# 2  This article presents a theoretical work whose...                     65
# 3  This paper is based on research of a socioling...                     58
#
#                                         Text ChatGPT
# 0  In this research article focusing on the fern ...
# 1  A flawless bacterial genome assembly is charac...
# 2  This article presents a theoretical work with ...
# 3  This paper presents a sociolinguistic and ethn...

# %% [markdown]
# #### Assigning section and paragraph information to each paragraph according to the definitions of the dictionary `section_paragraph_mapping`

# %%
# Setting up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s', handlers=[
    logging.FileHandler(f"{output_directory}/section_paragraph_test.log"),
    logging.StreamHandler()
])

# Reading the JSON file containing the dictionary 'section_paragraph_mapping'
with open(f"{output_directory}/section_paragraph_mapping.json", 'r') as json_file:
    section_paragraph_mapping = json.load(json_file)

# Initialising a list to store the new DataFrame rows
new_rows = []

# Iterating through the existing DataFrame with progress tracking
for index, row in tqdm(df_test.iterrows(), total=len(df_test), desc="Processing rows"):
    text_id = row['Text ID']
    paragraphs = row['Text Paragraphs'].split('\n')
    paragraph_index = 0

    if text_id in section_paragraph_mapping:
        sections = section_paragraph_mapping[text_id]
        dict_paragraph_count = sum(len(paragraphs) for paragraphs in sections.values())
        
        if dict_paragraph_count > len(paragraphs):
            logging.info(f"Text ID: {text_id} - Dictionary has more paragraphs ({dict_paragraph_count}) than text ({len(paragraphs)})")
        elif dict_paragraph_count < len(paragraphs):
            logging.info(f"Text ID: {text_id} - Text has more paragraphs ({len(paragraphs)}) than dictionary ({dict_paragraph_count}). The remaining paragraphs in the text will be left unprocessed.")
        else:
            logging.info(f"Text ID: {text_id} - Dictionary and text have the same number of paragraphs ({len(paragraphs)})")
        
        for section, paragraph_names in sections.items():
            for paragraph_name in paragraph_names:
                if paragraph_index < len(paragraphs):
                    paragraph_text = paragraphs[paragraph_index]
                    new_rows.append({
                        'Text ID': text_id,
                        'Section': section,
                        'Paragraph': paragraph_name,
                        'Text Paragraph': paragraph_text
                    })
                    paragraph_index += 1
                else:
                    logging.warning(f"Not enough paragraphs in text for {text_id}, section: {section}, paragraph: {paragraph_name}")
                    break
            if paragraph_index >= len(paragraphs):
                break
    else:
        logging.warning(f"{text_id} not found in section_paragraph_mapping")

# Creating the new DataFrame
df_new_test = pd.DataFrame(new_rows)

# Merging the new DataFrame with the existing DataFrame on 'Text ID'
df_merged_test = pd.merge(df_test.drop(columns=['Text', 'Text Paragraphs Count', 'Text Paragraphs', 'Text ChatGPT']), df_new_test, on='Text ID', how='right')

logging.info("Merging of DataFrames complete.")
# Out:
# Processing rows:   0%|          | 0/4 [00:00<?, ?it/s]2025-04-22 06:13:36,585 - INFO - Text ID: t000000 - Dictionary and text have the same number of paragraphs (29)
# 2025-04-22 06:13:36,587 - INFO - Text ID: t000001 - Dictionary and text have the same number of paragraphs (31)
# 2025-04-22 06:13:36,588 - INFO - Text ID: t000002 - Dictionary and text have the same number of paragraphs (65)
# 2025-04-22 06:13:36,590 - INFO - Text ID: t000003 - Dictionary and text have the same number of paragraphs (58)
# Processing rows: 100%|██████████| 4/4 [00:00<00:00, 354.74it/s]
# 2025-04-22 06:13:36,614 - INFO - Merging of DataFrames complete.

# %%
df_merged_test
# Out:
#                                                  Title  \
# 0    (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1    (Fern flora of Viçosa, Minas Gerais State, Bra...
# 2    (Fern flora of Viçosa, Minas Gerais State, Bra...
# 3    (Fern flora of Viçosa, Minas Gerais State, Bra...
# 4    (Fern flora of Viçosa, Minas Gerais State, Bra...
# ..                                                 ...
# 178  MOBILIZING LINGUISTIC AND SEMIOTIC RESOURCES, ...
# 179  MOBILIZING LINGUISTIC AND SEMIOTIC RESOURCES, ...
# 180  MOBILIZING LINGUISTIC AND SEMIOTIC RESOURCES, ...
# 181  MOBILIZING LINGUISTIC AND SEMIOTIC RESOURCES, ...
# 182  MOBILIZING LINGUISTIC AND SEMIOTIC RESOURCES, ...
#
#                                                    URL  \
# 0    https://preprints.scielo.org/index.php/scielo/...
# 1    https://preprints.scielo.org/index.php/scielo/...
# 2    https://preprints.scielo.org/index.php/scielo/...
# 3    https://preprints.scielo.org/index.php/scielo/...
# 4    https://preprints.scielo.org/index.php/scielo/...
# ..                                                 ...
# 178  https://preprints.scielo.org/index.php/scielo/...
# 179  https://preprints.scielo.org/index.php/scielo/...
# 180  https://preprints.scielo.org/index.php/scielo/...
# 181  https://preprints.scielo.org/index.php/scielo/...
# 182  https://preprints.scielo.org/index.php/scielo/...
#
#                                              Authors  \
# 0    Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 1    Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 2    Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 3    Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 4    Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# ..                                               ...
# 178             Estêvão Cabral, Marylin Martin-Jones
# 179             Estêvão Cabral, Marylin Martin-Jones
# 180             Estêvão Cabral, Marylin Martin-Jones
# 181             Estêvão Cabral, Marylin Martin-Jones
# 182             Estêvão Cabral, Marylin Martin-Jones
#
#                                     Published PDF Language  \
# 0    Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 1    Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 2    Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 3    Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 4    Submitted 11/22/2022 - Posted 11/23/2022          PDF
# ..                                        ...          ...
# 178  Submitted 11/07/2022 - Posted 11/07/2022          PDF
# 179  Submitted 11/07/2022 - Posted 11/07/2022          PDF
# 180  Submitted 11/07/2022 - Posted 11/07/2022          PDF
# 181  Submitted 11/07/2022 - Posted 11/07/2022          PDF
# 182  Submitted 11/07/2022 - Posted 11/07/2022          PDF
#
#                                                PDF URL  Submitted     Posted  \
# 0    https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-23
# 1    https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-23
# 2    https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-23
# 3    https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-23
# 4    https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-23
# ..                                                 ...        ...        ...
# 178  https://preprints.scielo.org/index.php/scielo/... 2022-11-07 2022-11-07
# 179  https://preprints.scielo.org/index.php/scielo/... 2022-11-07 2022-11-07
# 180  https://preprints.scielo.org/index.php/scielo/... 2022-11-07 2022-11-07
# 181  https://preprints.scielo.org/index.php/scielo/... 2022-11-07 2022-11-07
# 182  https://preprints.scielo.org/index.php/scielo/... 2022-11-07 2022-11-07
#
#      Text ID                Area of Knowledge  \
# 0    t000000              Biological Sciences
# 1    t000000              Biological Sciences
# 2    t000000              Biological Sciences
# 3    t000000              Biological Sciences
# 4    t000000              Biological Sciences
# ..       ...                              ...
# 178  t000003  Linguistic, literature and arts
# 179  t000003  Linguistic, literature and arts
# 180  t000003  Linguistic, literature and arts
# 181  t000003  Linguistic, literature and arts
# 182  t000003  Linguistic, literature and arts
#
#                              Section    Paragraph  \
# 0                           Abstract  Paragraph 1
# 1    Introduction, Literature Review  Paragraph 1
# 2    Introduction, Literature Review  Paragraph 2
# 3    Introduction, Literature Review  Paragraph 3
# 4    Introduction, Literature Review  Paragraph 4
# ..                               ...          ...
# 178                       Conclusion  Paragraph 2
# 179                       Conclusion  Paragraph 3
# 180                       Conclusion  Paragraph 4
# 181                       Conclusion  Paragraph 5
# 182                       Conclusion  Paragraph 6
#
#                                         Text Paragraph
# 0    (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1    At the end of the era in which the plant Class...
# 2    Brazil is represented by Dennstaedtiaceae with...
# 3    Pteridium is spread all across the globe (exce...
# 4    In the State of Minas Gerais, Dennstaedtiaceae...
# ..                                                 ...
# 178  Second, an orientation to national identity is...
# 179  Third, the case of the Timorese migrants in No...
# 180  Fourth, the dual focus on mobility and on the ...
# 181  And, finally, undertaking detailed ethnographi...
# 182  The only public data (about recent migration t...
#
# [183 rows x 13 columns]

# %%
df_merged_test.at[0, 'Text Paragraph']
# Out:
# '(Fern flora of Viçosa, Minas Gerais State, Brazil: Dennstaedtiaceae, Lindsaeaceae and Saccolomataceae). As part of an ongoing project treating the ferns and lycophytes from the region of Viçosa, Minas Gerais State, Brazil, we here present the taxonomic treatment of the early divergent lineages of the leptosporangiate ferns: the families Dennstaedtiaceae, Lindsaeaceae and Saccolomataceae. We have been sampling the remnant forest patches since 2012; we also fully reviewed the collection of herbarium VIC and other online collections: F, IAN, NY, PH, RB, U, UC, UPCB, US, and WTU. In the region of Viçosa, six taxa belonging to those families occur Dennstaedtia cicutaria and Pteridium esculentum subsp. arachnoideum (Dennstaedtiaceae); Lindsaea lancea var. lancea, L. quadrangularis subsp. quadrangularis, and L. stricta var. stricta (Lindsaeaceae); and Saccoloma elegans (Saccolomataceae). Among these taxa, only L. quadrangularis subsp. quadrangularis and S. elegans are endemic to the Brazilian Atlantic Rainforest; the remaining are widespread in the Neotropics. We present keys, descriptions, illustrations, examined specimens, and comments.'

# %%
df_merged_test.at[1, 'Text Paragraph']
# Out:
# 'At the end of the era in which the plant Classification Systems were mostly based on morphological data, Dennstaedtiaceae was considered a big family, comprehending three subfamilies (or tribes) and about 17 genera (Tryon & Tryon 1982, Kramer 1990). With the advent of molecular data, those subfamilies were raised to family-level, some families were created, and now the early- diverging leptosporangiate ferns are represented by Cystodiaceae (one genus), Dennstaedtiaceae with a stricter circumscription (11-12 genera), Lindsaeaceae (seven genera), Lonchitidaceae (one genus), Saccolomataceae (one or two genera), as well as the great Pteridaceae (+50 genera) (Smith et al. 2006, PPG I 2016, Shang et al. 2018, Schwartsburd et al. 2020).'

# %%
df_new_test.head(30)
# Out:
#     Text ID                          Section     Paragraph  \
# 0   t000000                         Abstract   Paragraph 1
# 1   t000000  Introduction, Literature Review   Paragraph 1
# 2   t000000  Introduction, Literature Review   Paragraph 2
# 3   t000000  Introduction, Literature Review   Paragraph 3
# 4   t000000  Introduction, Literature Review   Paragraph 4
# 5   t000000                      Methodology   Paragraph 1
# 6   t000000                      Methodology   Paragraph 2
# 7   t000000  Results, Discussion, Conclusion   Paragraph 1
# 8   t000000  Results, Discussion, Conclusion   Paragraph 2
# 9   t000000  Results, Discussion, Conclusion   Paragraph 3
# 10  t000000  Results, Discussion, Conclusion   Paragraph 4
# 11  t000000  Results, Discussion, Conclusion   Paragraph 5
# 12  t000000  Results, Discussion, Conclusion   Paragraph 6
# 13  t000000  Results, Discussion, Conclusion   Paragraph 7
# 14  t000000  Results, Discussion, Conclusion   Paragraph 8
# 15  t000000  Results, Discussion, Conclusion   Paragraph 9
# 16  t000000  Results, Discussion, Conclusion  Paragraph 10
# 17  t000000  Results, Discussion, Conclusion  Paragraph 11
# 18  t000000  Results, Discussion, Conclusion  Paragraph 12
# 19  t000000  Results, Discussion, Conclusion  Paragraph 13
# 20  t000000  Results, Discussion, Conclusion  Paragraph 14
# 21  t000000  Results, Discussion, Conclusion  Paragraph 15
# 22  t000000  Results, Discussion, Conclusion  Paragraph 16
# 23  t000000  Results, Discussion, Conclusion  Paragraph 17
# 24  t000000  Results, Discussion, Conclusion  Paragraph 18
# 25  t000000  Results, Discussion, Conclusion  Paragraph 19
# 26  t000000  Results, Discussion, Conclusion  Paragraph 20
# 27  t000000  Results, Discussion, Conclusion  Paragraph 21
# 28  t000000                 Acknowledgements   Paragraph 1
# 29  t000001                         Abstract   Paragraph 1
#
#                                        Text Paragraph
# 0   (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1   At the end of the era in which the plant Class...
# 2   Brazil is represented by Dennstaedtiaceae with...
# 3   Pteridium is spread all across the globe (exce...
# 4   In the State of Minas Gerais, Dennstaedtiaceae...
# 5   In the region of Viçosa, Minas Gerais State, B...
# 6   We have been sampling the remnant forest patch...
# 7   Dennstaedtiaceae, Lindsaeaceae, and Saccolomat...
# 8   Rhizomes generaly long-creeping, solenostelic ...
# 9   The family is cosmopolitan, composed of eleven...
# 10  Rhizomes short to long-creeping, glabrous or w...
# 11  Dennstaedtia is polyphyletic in current circum...
# 12  Plants terrestrial. Rhizomes long-creeping, wi...
# 13  Dennstaedtia cicutaria is recognized by veins ...
# 14  Rhizomes long-creeping, with setose hairs. Lea...
# 15  Two species plus two species with hybrid origi...
# 16  Plants terrestrial, ticket-forming. Rhizomes l...
# 17  Pteridium esculentum subsp. arachnoideum is re...
# 18  Rhizomes short to long-creeping, protostelic w...
# 19  Rhizomes short-creeping, with primitive scales...
# 20  About 180 species, with 34 spp. occurring in B...
# 21  Plants terrestrial. Rhizomes short-creeping, w...
# 22  All Lindsaea spp. from Viçosa are similar in h...
# 23  Plants terrestrial. Rhizomes short-creeping, w...
# 24  Plants terrestrial. Rhizomes short-creeping, w...
# 25  Rhizomes erect or rarely short-creeping, somet...
# 26  One pantropical genus with about 24 species (R...
# 27  Plants terrestrial. Rhizomes erect to decumben...
# 28  We thank Universidade Federal de Viçosa (UFV) ...
# 29  A perfect bacterial genome assembly is one whe...

# %%
df_new_test.iloc[124:183]
# Out:
#      Text ID                           Section     Paragraph  \
# 124  t000002            Discussion, Conclusion   Paragraph 7
# 125  t000003                          Abstract   Paragraph 1
# 126  t000003                      Introduction   Paragraph 1
# 127  t000003                      Introduction   Paragraph 2
# 128  t000003                      Introduction   Paragraph 3
# 129  t000003                      Introduction   Paragraph 4
# 130  t000003                 Literature Review   Paragraph 1
# 131  t000003                 Literature Review   Paragraph 2
# 132  t000003                 Literature Review   Paragraph 3
# 133  t000003                 Literature Review   Paragraph 4
# 134  t000003                 Literature Review   Paragraph 5
# 135  t000003                 Literature Review   Paragraph 6
# 136  t000003                 Literature Review   Paragraph 7
# 137  t000003                 Literature Review   Paragraph 8
# 138  t000003                 Literature Review   Paragraph 9
# 139  t000003                 Literature Review  Paragraph 10
# 140  t000003                 Literature Review  Paragraph 11
# 141  t000003  Methodology, Results, Discussion   Paragraph 1
# 142  t000003  Methodology, Results, Discussion   Paragraph 2
# 143  t000003  Methodology, Results, Discussion   Paragraph 3
# 144  t000003  Methodology, Results, Discussion   Paragraph 4
# 145  t000003  Methodology, Results, Discussion   Paragraph 5
# 146  t000003  Methodology, Results, Discussion   Paragraph 6
# 147  t000003  Methodology, Results, Discussion   Paragraph 7
# 148  t000003  Methodology, Results, Discussion   Paragraph 8
# 149  t000003  Methodology, Results, Discussion   Paragraph 9
# 150  t000003  Methodology, Results, Discussion  Paragraph 10
# 151  t000003  Methodology, Results, Discussion  Paragraph 11
# 152  t000003  Methodology, Results, Discussion  Paragraph 12
# 153  t000003  Methodology, Results, Discussion  Paragraph 13
# 154  t000003  Methodology, Results, Discussion  Paragraph 14
# 155  t000003  Methodology, Results, Discussion  Paragraph 15
# 156  t000003  Methodology, Results, Discussion  Paragraph 16
# 157  t000003  Methodology, Results, Discussion  Paragraph 17
# 158  t000003  Methodology, Results, Discussion  Paragraph 18
# 159  t000003  Methodology, Results, Discussion  Paragraph 19
# 160  t000003  Methodology, Results, Discussion  Paragraph 20
# 161  t000003  Methodology, Results, Discussion  Paragraph 21
# 162  t000003  Methodology, Results, Discussion  Paragraph 22
# 163  t000003  Methodology, Results, Discussion  Paragraph 23
# 164  t000003  Methodology, Results, Discussion  Paragraph 24
# 165  t000003  Methodology, Results, Discussion  Paragraph 25
# 166  t000003  Methodology, Results, Discussion  Paragraph 26
# 167  t000003  Methodology, Results, Discussion  Paragraph 27
# 168  t000003  Methodology, Results, Discussion  Paragraph 28
# 169  t000003  Methodology, Results, Discussion  Paragraph 29
# 170  t000003  Methodology, Results, Discussion  Paragraph 30
# 171  t000003  Methodology, Results, Discussion  Paragraph 31
# 172  t000003  Methodology, Results, Discussion  Paragraph 32
# 173  t000003  Methodology, Results, Discussion  Paragraph 33
# 174  t000003  Methodology, Results, Discussion  Paragraph 34
# 175  t000003  Methodology, Results, Discussion  Paragraph 35
# 176  t000003  Methodology, Results, Discussion  Paragraph 36
# 177  t000003                        Conclusion   Paragraph 1
# 178  t000003                        Conclusion   Paragraph 2
# 179  t000003                        Conclusion   Paragraph 3
# 180  t000003                        Conclusion   Paragraph 4
# 181  t000003                        Conclusion   Paragraph 5
# 182  t000003                        Conclusion   Paragraph 6
#
#                                         Text Paragraph
# 124  Here, I argue for a complementarity stance mai...
# 125  This paper is based on research of a socioling...
# 126  This paper draws on research, of a sociolingui...
# 127  In this paper, we focus on one particular life...
# 128  Our research revealed the situated and multifa...
# 129  The orienting theories for our research come f...
# 130  The last decade of the twentieth century and t...
# 131  By the first decade of the twenty first centur...
# 132  For most of the twentieth century, the dominan...
# 133  Along with this critique of essentialised noti...
# 134  In his volume on the sociolinguistics of globa...
# 135  As the mobility paradigm has been developed in...
# 136  Aligning ourselves with this strand of work, w...
# 137  Mooring and remooring imply considerable agenc...
# 138  Locating our research with Timorese migrants i...
# 139  At the same time, we are keenly aware of the f...
# 140  For this reason, our broader research project ...
# 141  The first major outward movement of Timorese c...
# 142  Since Independence in 2002, there has been a n...
# 143  Many of those who have taken up this entitleme...
# 144  There have been two overlapping routes into em...
# 145  We made our first field visits to Northern Ire...
# 146  From our participant observation and our inter...
# 147  All members of the core group had had some mod...
# 148  All members of the core group had had some mod...
# 149  Some of our interviewees had spent some time i...
# 150  Two of those we interviewed in June 2015 (RS a...
# 151  Three of these young Timorese (RS, HA and MFB)...
# 152  The communicative challenges faced by new arri...
# 153  While there has been a significant pattern of ...
# 154  The small number of migrants arriving in North...
# 155  However, those who indicated that they had exp...
# 156  Most of the rental accommodation available in ...
# 157  The Timorese arriving in Dungannon, or other l...
# 158  Two local employment agencies act as the gatek...
# 159  The ability to speak English is increasingly u...
# 160  As we have shown above, the Timorese migrants ...
# 161  There are different groups of Timorese, with p...
# 162  We provide an account of three different aspec...
# 163  It was in October 2014 that we learned that th...
# 164  The Young Crocs team was organised for Timores...
# 165  The six other teams included a mix of adult pl...
# 166  All the names of the football clubs were compo...
# 167  A range of semiotic resources were creatively ...
# 168  All these logos incorporate images that link t...
# 169  Colour was used symbolically in other ways too...
# 170  Our interviews with football club organisers, ...
# 171  Some of the club organisers and managers incor...
# 172  The football tournaments involving these Timor...
# 173  The photograph on the left shows the cup and i...
# 174  In addition to the annual tournaments, individ...
# 175  Narrowing our research lens, and focusing in o...
# 176  Despite this diversity in the team-specific pr...
# 177  Our aim in this paper has been to make a contr...
# 178  Second, an orientation to national identity is...
# 179  Third, the case of the Timorese migrants in No...
# 180  Fourth, the dual focus on mobility and on the ...
# 181  And, finally, undertaking detailed ethnographi...
# 182  The only public data (about recent migration t...

# %% [markdown]
# #### Exporting to a file

# %%
df_merged_test.to_json(f"{output_directory}/scielo_erpp_pp_test.jsonl", orient='records', lines=True)

# %% [markdown]
# #### Revising the paragraphs with ChatGPT

# %% [markdown]
# The programme `cl_st1_ph5_test_eyamrog.py` was adapted for command line for better efficiency running on an AWS EC2 instance.
#
# - Update the `.env` file with the actual OpenAI API Key
# - Activate the corresponding Python environment
# - Run it as
#
# ```
# (my_env) eyamrog@Rog-ASUS:~/work/cl_st1_eyamrog$ nohup python cl_st1_ph5_test_eyamrog.py cl_st1_ph5_eyamrog cl_st1_ph5_eyamrog &
# ```

# %% [markdown]
# ### Creating the dictionary `section_paragraph_mapping`

# %% [markdown]
# As the dictionary `section_paragraph_mapping` is gradually created, the programme `section_paragraph_mapping_validate.py` should be used to validate it.

# %% [markdown]
# ### Assigning section and paragraph information to each paragraph according to the definitions of the dictionary `section_paragraph_mapping`

# %%
# Setting up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s', handlers=[
    logging.FileHandler(f"{output_directory}/section_paragraph.log"),
    logging.StreamHandler()
])

# Reading the JSON file containing the dictionary 'section_paragraph_mapping'
with open(f"{output_directory}/section_paragraph_mapping.json", 'r') as json_file:
    section_paragraph_mapping = json.load(json_file)

# Initialising a list to store the new DataFrame rows
new_rows = []

# Iterating through the existing DataFrame with progress tracking
for index, row in tqdm(df_scielo_preprint_preChatGPT_en.iterrows(), total=len(df_scielo_preprint_preChatGPT_en), desc="Processing rows"):
    text_id = row['Text ID']
    paragraphs = row['Text Paragraphs'].split('\n')
    paragraph_index = 0

    if text_id in section_paragraph_mapping:
        sections = section_paragraph_mapping[text_id]
        dict_paragraph_count = sum(len(paragraphs) for paragraphs in sections.values())
        
        if dict_paragraph_count > len(paragraphs):
            logging.info(f"Text ID: {text_id} - Dictionary has more paragraphs ({dict_paragraph_count}) than text ({len(paragraphs)})")
        elif dict_paragraph_count < len(paragraphs):
            logging.info(f"Text ID: {text_id} - Text has more paragraphs ({len(paragraphs)}) than dictionary ({dict_paragraph_count}). The remaining paragraphs in the text will be left unprocessed.")
        else:
            logging.info(f"Text ID: {text_id} - Dictionary and text have the same number of paragraphs ({len(paragraphs)})")
        
        for section, paragraph_names in sections.items():
            for paragraph_name in paragraph_names:
                if paragraph_index < len(paragraphs):
                    paragraph_text = paragraphs[paragraph_index]
                    new_rows.append({
                        'Text ID': text_id,
                        'Section': section,
                        'Paragraph': paragraph_name,
                        'Text Paragraph': paragraph_text
                    })
                    paragraph_index += 1
                else:
                    logging.warning(f"Not enough paragraphs in text for {text_id}, section: {section}, paragraph: {paragraph_name}")
                    break
            if paragraph_index >= len(paragraphs):
                break
    else:
        logging.warning(f"{text_id} not found in section_paragraph_mapping")

# Creating the new DataFrame
df_new = pd.DataFrame(new_rows)

# Merging the new DataFrame with the existing DataFrame on 'Text ID'
df_merged = pd.merge(df_scielo_preprint_preChatGPT_en.drop(columns=['Text', 'Text Paragraphs Count', 'Text Paragraphs', 'Text ChatGPT']), df_new, on='Text ID', how='right')

logging.info("Merging of DataFrames complete.")
# Out:
# Processing rows:   0%|          | 0/316 [00:00<?, ?it/s]2025-04-22 06:14:13,214 - INFO - Text ID: t000000 - Dictionary and text have the same number of paragraphs (29)
# 2025-04-22 06:14:13,215 - INFO - Text ID: t000001 - Dictionary and text have the same number of paragraphs (31)
# 2025-04-22 06:14:13,217 - INFO - Text ID: t000002 - Dictionary and text have the same number of paragraphs (65)
# 2025-04-22 06:14:13,218 - INFO - Text ID: t000003 - Dictionary and text have the same number of paragraphs (58)
# 2025-04-22 06:14:13,220 - INFO - Text ID: t000004 - Dictionary and text have the same number of paragraphs (123)
# 2025-04-22 06:14:13,221 - INFO - Text ID: t000005 - Dictionary and text have the same number of paragraphs (15)
# 2025-04-22 06:14:13,222 - INFO - Text ID: t000006 - Dictionary and text have the same number of paragraphs (38)
# 2025-04-22 06:14:13,223 - INFO - Text ID: t000007 - Dictionary and text have the same number of paragraphs (28)
# 2025-04-22 06:14:13,224 - INFO - Text ID: t000008 - Dictionary and text have the same number of paragraphs (22)
# 2025-04-22 06:14:13,225 - INFO - Text ID: t000009 - Dictionary and text have the same number of paragraphs (58)
# 2025-04-22 06:14:13,225 - INFO - Text ID: t000010 - Dictionary and text have the same number of paragraphs (38)
# 2025-04-22 06:14:13,227 - INFO - Text ID: t000011 - Dictionary and text have the same number of paragraphs (21)
# 2025-04-22 06:14:13,227 - INFO - Text ID: t000012 - Dictionary and text have the same number of paragraphs (20)
# 2025-04-22 06:14:13,228 - INFO - Text ID: t000013 - Dictionary and text have the same number of paragraphs (96)
# 2025-04-22 06:14:13,229 - INFO - Text ID: t000014 - Dictionary and text have the same number of paragraphs (94)
# 2025-04-22 06:14:13,230 - INFO - Text ID: t000015 - Dictionary and text have the same number of paragraphs (34)
# 2025-04-22 06:14:13,231 - INFO - Text ID: t000016 - Dictionary and text have the same number of paragraphs (26)
# 2025-04-22 06:14:13,232 - INFO - Text ID: t000017 - Dictionary and text have the same number of paragraphs (39)
# 2025-04-22 06:14:13,233 - INFO - Text ID: t000018 - Dictionary and text have the same number of paragraphs (50)
# 2025-04-22 06:14:13,234 - INFO - Text ID: t000019 - Dictionary and text have the same number of paragraphs (84)
# 2025-04-22 06:14:13,235 - INFO - Text ID: t000020 - Dictionary and text have the same number of paragraphs (34)
# 2025-04-22 06:14:13,236 - INFO - Text ID: t000021 - Dictionary and text have the same number of paragraphs (57)
# 2025-04-22 06:14:13,237 - INFO - Text ID: t000022 - Dictionary and text have the same number of paragraphs (72)
# 2025-04-22 06:14:13,237 - INFO - Text ID: t000023 - Dictionary and text have the same number of paragraphs (76)
# 2025-04-22 06:14:13,238 - INFO - Text ID: t000024 - Dictionary and text have the same number of paragraphs (29)
# 2025-04-22 06:14:13,239 - INFO - Text ID: t000025 - Dictionary and text have the same number of paragraphs (86)
# 2025-04-22 06:14:13,241 - INFO - Text ID: t000026 - Dictionary and text have the same number of paragraphs (43)
# 2025-04-22 06:14:13,242 - INFO - Text ID: t000027 - Dictionary and text have the same number of paragraphs (39)
# 2025-04-22 06:14:13,244 - INFO - Text ID: t000028 - Dictionary and text have the same number of paragraphs (105)
# 2025-04-22 06:14:13,245 - INFO - Text ID: t000029 - Dictionary and text have the same number of paragraphs (58)
# 2025-04-22 06:14:13,246 - INFO - Text ID: t000030 - Dictionary and text have the same number of paragraphs (69)
# 2025-04-22 06:14:13,247 - INFO - Text ID: t000031 - Dictionary and text have the same number of paragraphs (5)
# 2025-04-22 06:14:13,248 - INFO - Text ID: t000032 - Dictionary and text have the same number of paragraphs (30)
# 2025-04-22 06:14:13,249 - INFO - Text ID: t000033 - Dictionary and text have the same number of paragraphs (31)
# 2025-04-22 06:14:13
Fern flora of Viçosa, Minas Gerais State, Bra...
# 1      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 2      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 3      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 4      (Fern flora of Viçosa, Minas Gerais State, Bra...
# ...                                                  ...
# 11522  COVID-19 in Brazil: advantages of a socialized...
# 11523  COVID-19 in Brazil: advantages of a socialized...
# 11524  COVID-19 in Brazil: advantages of a socialized...
# 11525  COVID-19 in Brazil: advantages of a socialized...
# 11526  COVID-19 in Brazil: advantages of a socialized...
#
#                                                      URL  \
# 0      https://preprints.scielo.org/index.php/scielo/...
# 1      https://preprints.scielo.org/index.php/scielo/...
# 2      https://preprints.scielo.org/index.php/scielo/...
# 3      https://preprints.scielo.org/index.php/scielo/...
# 4      https://preprints.scielo.org/index.php/scielo/...
# ...                                                  ...
# 11522  https://preprints.scielo.org/index.php/scielo/...
# 11523  https://preprints.scielo.org/index.php/scielo/...
# 11524  https://preprints.scielo.org/index.php/scielo/...
# 11525  https://preprints.scielo.org/index.php/scielo/...
# 11526  https://preprints.scielo.org/index.php/scielo/...
#
#                                                  Authors  \
# 0        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 1        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 2        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 3        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 4        Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# ...                                                  ...
# 11522  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
# 11523  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
# 11524  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
# 11525  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
# 11526  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
#
#                                       Published PDF Language  \
# 0      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 1      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 2      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 3      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 4      Submitted 11/22/2022 - Posted 11/23/2022          PDF
# ...                                         ...          ...
# 11522  Submitted 04/06/2020 - Posted 04/08/2020          PDF
# 11523  Submitted 04/06/2020 - Posted 04/08/2020          PDF
# 11524  Submitted 04/06/2020 - Posted 04/08/2020          PDF
# 11525  Submitted 04/06/2020 - Posted 04/08/2020          PDF
# 11526  Submitted 04/06/2020 - Posted 04/08/2020          PDF
#
#                                                  PDF URL  Submitted  \
# 0      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 1      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 2      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 3      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# 4      https://preprints.scielo.org/index.php/scielo/... 2022-11-22
# ...                                                  ...        ...
# 11522  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
# 11523  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
# 11524  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
# 11525  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
# 11526  https://preprints.scielo.org/index.php/scielo/... 2020-04-06
#
#           Posted  Text ID    Area of Knowledge  \
# 0     2022-11-23  t000000  Biological Sciences
# 1     2022-11-23  t000000  Biological Sciences
# 2     2022-11-23  t000000  Biological Sciences
# 3     2022-11-23  t000000  Biological Sciences
# 4     2022-11-23  t000000  Biological Sciences
# ...          ...      ...                  ...
# 11522 2020-04-08  t000315      Health Sciences
# 11523 2020-04-08  t000315      Health Sciences
# 11524 2020-04-08  t000315      Health Sciences
# 11525 2020-04-08  t000315      Health Sciences
# 11526 2020-04-08  t000315      Health Sciences
#
#                                                  Section     Paragraph  \
# 0                                               Abstract   Paragraph 1
# 1                        Introduction, Literature Review   Paragraph 1
# 2                        Introduction, Literature Review   Paragraph 2
# 3                        Introduction, Literature Review   Paragraph 3
# 4                        Introduction, Literature Review   Paragraph 4
# ...                                                  ...           ...
# 11522  Literature Review, Methodology, Results, Discu...  Paragraph 14
# 11523  Literature Review, Methodology, Results, Discu...  Paragraph 15
# 11524  Literature Review, Methodology, Results, Discu...  Paragraph 16
# 11525  Literature Review, Methodology, Results, Discu...  Paragraph 17
# 11526                                   Acknowledgements   Paragraph 1
#
#                                           Text Paragraph
# 0      (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1      At the end of the era in which the plant Class...
# 2      Brazil is represented by Dennstaedtiaceae with...
# 3      Pteridium is spread all across the globe (exce...
# 4      In the State of Minas Gerais, Dennstaedtiaceae...
# ...                                                  ...
# 11522  During the Zika epidemic, Brazil led the disco...
# 11523  Although Brazil is attempting to implement mea...
# 11524  Regarding cultural differences, the use of mas...
# 11525  Physical distancing is a measure that should b...
# 11526  We thank Judith Recht for the critical review ...
#
# [11527 rows x 13 columns]

# %% [markdown]
# #### Detecting empty paragraphs in the column `Text Paragragh`

# %% [markdown]
# ##### Detecting `NaN` (null value) in the column `Text Paragraph`

# %%
print(df_merged['Text Paragraph'].isnull().sum())
# Out:
# 0

# %% [markdown]
# ##### Detecting empty strings in the column `Text Paragraph`

# %%
print((df_merged['Text Paragraph'] == '').sum())
# Out:
# 8

# %% [markdown]
# ##### Detecting both `NaN` and empty strings in the column `Text Paragraph`

# %%
print(df_merged['Text Paragraph'].apply(lambda x: x is None or x == '').sum())
# Out:
# 8

# %% [markdown]
# #### Inspecting a few data

# %%
df_merged.at[3411, 'Text Paragraph']
# Out:
# ''

# %%
df_merged.at[6610, 'Text Paragraph']
# Out:
# '𝐻0 : 𝛽2 = 𝛽3 = 𝛽5 = 𝛽6 = 0 (2) 𝐻1 : 𝛽2 ≠𝛽3 ≠𝛽5 ≠𝛽6 ≠0 (3)'

# %%
df_merged.at[2611, 'Text Paragraph']
# Out:
# 'Whether the purpose of NATO expansion is seen as an attempt to prevent the formation of a Eurasian alliance (KLARE, 2022), a “justifiable response to the […] entreaties of new Central and Eastern European democracies” (SAROTTE, 2021) that contributed to the frustration of East-West cooperation, or “the most fateful error in the entire post-Cold War era” (KENNAN, 1997) always depends on one’s standpoint; there is no “objective position”. It is a central contention of Bakhtinian dialogism that we do not only engage in talk about discourse, but with discourse, and that a form of dialogical understanding always includes evaluation and response Todorov (1984, p.16). In the continuously changing realm of politics, any analyst not only observes political processes, but also shapes them, so that “decision and standpoint are inseparably bound up together” (MANNHEIM, 1936, p.152). Individual standpoints, also sometimes called researcher bias, thus unavoidably permeate any type of analysis (DAVIS, 1990, p.16; GEE, 2011, p.9). It is with this perspective in mind that I will proceed to outline the method in the following section.'

# %% [markdown]
# #### Exporting to a file

# %%
df_merged.to_json(f"{output_directory}/scielo_erpp_pp.jsonl", orient='records', lines=True)

# %%
df_merged.to_excel(f"{output_directory}/scielo_erpp_pp.xlsx")

# %% [markdown]
# ## Revising the paragraphs with ChatGPT

# %% [markdown]
# The programme `cl_st1_ph5_eyamrog.py` was adapted for command line for better efficiency running on an AWS EC2 instance.
#
# - Update the `.env` file with the actual OpenAI API Key
# - Activate the corresponding Python environment
# - Run it as
#
# ```
# (my_env) eyamrog@Rog-ASUS:~/work/cl_st1_eyamrog$ nohup python cl_st1_ph5_eyamrog.py cl_st1_ph5_eyamrog cl_st1_ph5_eyamrog &
# ```
