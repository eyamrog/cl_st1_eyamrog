# %% [markdown]
# <center>
# <img src="https://laelgelcpublic.s3.sa-east-1.amazonaws.com/lael_50_years_narrow_white.png.no_years.400px_96dpi.png" width="300" alt="LAEL 50 years logo">
# <h3>APPLIED LINGUISTICS GRADUATE PROGRAMME (LAEL)</h3>
# </center>
# <hr>

# %% [markdown]
# # Corpus Linguistics - Study 1 - Phase 3 - eyamrog

# %% [markdown]
# The aim of this phase is to PDF scrape the selected texts from the archive of preprints of [SciELO](https://scielo.org/) (Scientific Electronic Library Online), inspect the articles and select the ones that are within the scope of this study.
#
# - [SciELO Preprints](https://preprints.scielo.org/index.php/scielo)

# %% [markdown]
# ## Required Python packages

# %% [markdown]
# - beautifulsoup4
# - PyMuPDF
# - lxml
# - pandas
# - requests

# %% [markdown]
# ## Importing the required libraries

# %%
import requests
from bs4 import BeautifulSoup
import fitz # PyMuPDF
import re
import pandas as pd
import os
import sys
import logging

# %% [markdown]
# ## Defining input variables

# %%
input_directory = 'cl_st1_ph2_eyamrog'
output_directory = 'cl_st1_ph3_eyamrog'

# %% [markdown]
# ## Creating output directory

# %%
# Check if the output directory already exists. If it does, do nothing. If it doesn't exist, create it.
if os.path.exists(output_directory):
    print('Output directory already exists.')
else:
    try:
        os.makedirs(output_directory)
        print('Output directory successfully created.')
    except OSError as e:
        print('Failed to create the directory:', e)
        sys.exit(1)
# Out:
# Output directory successfully created.

# %% [markdown]
# ## PDF Scraping `SciELO Preprints` archive

# %% [markdown]
# ### Importing the data into a DataFrame

# %%
df_scielo_preprint_preChatGPT_en = pd.read_json(f'{input_directory}/scielo_preprint_preChatGPT_en.jsonl', lines=True)

# %%
df_scielo_preprint_preChatGPT_en.dtypes
# Out:
# Title           object
# URL             object
# Authors         object
# Published       object
# PDF Language    object
# PDF URL         object
# Submitted        int64
# Posted           int64
# dtype: object

# %%
df_scielo_preprint_preChatGPT_en['Submitted'] = pd.to_datetime(df_scielo_preprint_preChatGPT_en['Submitted'], unit='ms')
df_scielo_preprint_preChatGPT_en['Posted'] = pd.to_datetime(df_scielo_preprint_preChatGPT_en['Posted'], unit='ms')

# %% [markdown]
# ### Creating the column `Text ID`

# %%
df_scielo_preprint_preChatGPT_en['Text ID'] = 't' + df_scielo_preprint_preChatGPT_en.index.astype(str).str.zfill(6)

# %%
df_scielo_preprint_preChatGPT_en
# Out:
#                                                  Title  \
# 0    (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1    Belching as a symptom of COVID-19: Case presen...
# 2    Assembling the perfect bacterial genome using ...
# 3    ON METHODOLOGY AND METHODS FOR ANALYSING CLASS...
# 4    MOBILIZING LINGUISTIC AND SEMIOTIC RESOURCES, ...
# ..                                                 ...
# 356  Information about the new coronavirus disease ...
# 357  ACE2 diversity in placental mammals reveals th...
# 358  Coronavirus 2: Analysis of Regularity of Compl...
# 359  MULTIPROFESSIONAL ELECTRONIC PROTOCOL FOR DIGE...
# 360  COVID-19 in Brazil: advantages of a socialized...
#
#                                                    URL  \
# 0    https://preprints.scielo.org/index.php/scielo/...
# 1    https://preprints.scielo.org/index.php/scielo/...
# 2    https://preprints.scielo.org/index.php/scielo/...
# 3    https://preprints.scielo.org/index.php/scielo/...
# 4    https://preprints.scielo.org/index.php/scielo/...
# ..                                                 ...
# 356  https://preprints.scielo.org/index.php/scielo/...
# 357  https://preprints.scielo.org/index.php/scielo/...
# 358  https://preprints.scielo.org/index.php/scielo/...
# 359  https://preprints.scielo.org/index.php/scielo/...
# 360  https://preprints.scielo.org/index.php/scielo/...
#
#                                                Authors  \
# 0      Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 1    Nuvia Novoa Acosta, Liuba Yamila Peña Galbán, ...
# 2        Ryan R. Wick, Louise M. Judd, Kathryn E. Holt
# 3                              Leonardo Goncalves Lago
# 4                 Estêvão Cabral, Marylin Martin-Jones
# ..                                                 ...
# 356            Claudio Márcio Amaral de Oliveira  Lima
# 357  Bibiana Sampaio de Oliveira Fam, Pedro Vargas-...
# 358                                 Yuri Morales-López
# 359  Osvaldo Malafaia, Faruk Abrão  KALIL-FILHO, Jo...
# 360  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
#
#                                     Published PDF Language  \
# 0    Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 1    Submitted 11/14/2022 - Posted 11/29/2022          PDF
# 2    Submitted 11/11/2022 - Posted 11/11/2022          PDF
# 3    Submitted 11/10/2022 - Posted 11/16/2022          PDF
# 4    Submitted 11/07/2022 - Posted 11/07/2022          PDF
# ..                                        ...          ...
# 356  Submitted 04/13/2020 - Posted 04/13/2020          PDF
# 357  Submitted 04/11/2020 - Posted 04/28/2020          PDF
# 358  Submitted 04/10/2020 - Posted 06/04/2020          PDF
# 359  Submitted 04/09/2020 - Posted 04/09/2020          PDF
# 360  Submitted 04/06/2020 - Posted 04/08/2020          PDF
#
#                                                PDF URL  Submitted     Posted  \
# 0    https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-23
# 1    https://preprints.scielo.org/index.php/scielo/... 2022-11-14 2022-11-29
# 2    https://preprints.scielo.org/index.php/scielo/... 2022-11-11 2022-11-11
# 3    https://preprints.scielo.org/index.php/scielo/... 2022-11-10 2022-11-16
# 4    https://preprints.scielo.org/index.php/scielo/... 2022-11-07 2022-11-07
# ..                                                 ...        ...        ...
# 356  https://preprints.scielo.org/index.php/scielo/... 2020-04-13 2020-04-13
# 357  https://preprints.scielo.org/index.php/scielo/... 2020-04-11 2020-04-28
# 358  https://preprints.scielo.org/index.php/scielo/... 2020-04-10 2020-06-04
# 359  https://preprints.scielo.org/index.php/scielo/... 2020-04-09 2020-04-09
# 360  https://preprints.scielo.org/index.php/scielo/... 2020-04-06 2020-04-08
#
#      Text ID
# 0    t000000
# 1    t000001
# 2    t000002
# 3    t000003
# 4    t000004
# ..       ...
# 356  t000356
# 357  t000357
# 358  t000358
# 359  t000359
# 360  t000360
#
# [361 rows x 9 columns]

# %% [markdown]
# ### Extracting the articles in original PDF format and scraping them into TXT format

# %%
# Configure logging to write to a file
logging.basicConfig(
    filename = f"{output_directory}/scraping_log.txt",
    level = logging.INFO,
    format = '%(asctime)s - %(levelname)s - %(message)s'
)

def scrape_pdf(pdf_byte_stream, output_txt):
    try:
        # Opening the PDF file
        doc = fitz.open(stream=pdf_byte_stream, filetype='pdf')
        
        # Initialising an empty string to store the text
        text = ''
        
        # Iterating through all the pages and extracting the text
        for page in doc:
            text += page.get_text()
        
        # Writing the extracted text to a text file in UTF-8 encoding
        with open(output_txt, 'w', encoding='utf-8') as txt_file:
            txt_file.write(text)
        
        logging.info(f"Text successfully extracted and saved to {output_txt}")
    except Exception as e:
        logging.error(f"Error extracting text from PDF: {e}")

def save_pdf(pdf_byte_stream, output_pdf):
    try:
        with open(output_pdf, 'wb') as pdf_file:
            pdf_file.write(pdf_byte_stream)
        
        logging.info(f"PDF successfully saved to {output_pdf}")
    except Exception as e:
        logging.error(f"Error saving PDF: {e}")

for index, row in df_scielo_preprint_preChatGPT_en.iterrows():
    try:
        article_page = requests.get(row['PDF URL'], verify=False)
        soup = BeautifulSoup(article_page.content, 'lxml')
        # Finding the <a> tag with the class 'download'
        download_link = soup.find('a', class_='download')
        article_pdf_link = download_link.get('href') if download_link else 'No PDF link'
        
        if article_pdf_link != 'No PDF link':
            article = requests.get(article_pdf_link, verify=False)
            # Scraping the article from the byte stream and saving it in the output directory
            scrape_pdf(article.content, f"{output_directory}/{row['Text ID']}.txt")
            # Saving the article in the output directory
            save_pdf(article.content, f"{output_directory}/{row['Text ID']}.pdf")
        else:
            logging.warning(f"No PDF link found for Text ID {row['Text ID']}")
    except Exception as e:
        logging.error(f"Error processing row {index}: {e}")

# %% [markdown]
# ## Adding the column `Text` with the text extracted from each article

# %%
# Function to read the content of a TXT file
def read_txt_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return file.read()

# Iterate through each row in the DataFrame and add the text content
texts = []
for index, row in df_scielo_preprint_preChatGPT_en.iterrows():
    text_id = row['Text ID']
    txt_file_path = os.path.join(output_directory, f"{text_id}.txt")
    if os.path.exists(txt_file_path):
        text_content = read_txt_file(txt_file_path)
    else:
        text_content = None  # or you can set it to an empty string or any default value
    texts.append(text_content)

# Add the 'Text' column to the DataFrame
df_scielo_preprint_preChatGPT_en['Text'] = texts

# %%
df_scielo_preprint_preChatGPT_en
# Out:
#                                                  Title  \
# 0    (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1    Belching as a symptom of COVID-19: Case presen...
# 2    Assembling the perfect bacterial genome using ...
# 3    ON METHODOLOGY AND METHODS FOR ANALYSING CLASS...
# 4    MOBILIZING LINGUISTIC AND SEMIOTIC RESOURCES, ...
# ..                                                 ...
# 356  Information about the new coronavirus disease ...
# 357  ACE2 diversity in placental mammals reveals th...
# 358  Coronavirus 2: Analysis of Regularity of Compl...
# 359  MULTIPROFESSIONAL ELECTRONIC PROTOCOL FOR DIGE...
# 360  COVID-19 in Brazil: advantages of a socialized...
#
#                                                    URL  \
# 0    https://preprints.scielo.org/index.php/scielo/...
# 1    https://preprints.scielo.org/index.php/scielo/...
# 2    https://preprints.scielo.org/index.php/scielo/...
# 3    https://preprints.scielo.org/index.php/scielo/...
# 4    https://preprints.scielo.org/index.php/scielo/...
# ..                                                 ...
# 356  https://preprints.scielo.org/index.php/scielo/...
# 357  https://preprints.scielo.org/index.php/scielo/...
# 358  https://preprints.scielo.org/index.php/scielo/...
# 359  https://preprints.scielo.org/index.php/scielo/...
# 360  https://preprints.scielo.org/index.php/scielo/...
#
#                                                Authors  \
# 0      Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 1    Nuvia Novoa Acosta, Liuba Yamila Peña Galbán, ...
# 2        Ryan R. Wick, Louise M. Judd, Kathryn E. Holt
# 3                              Leonardo Goncalves Lago
# 4                 Estêvão Cabral, Marylin Martin-Jones
# ..                                                 ...
# 356            Claudio Márcio Amaral de Oliveira  Lima
# 357  Bibiana Sampaio de Oliveira Fam, Pedro Vargas-...
# 358                                 Yuri Morales-López
# 359  Osvaldo Malafaia, Faruk Abrão  KALIL-FILHO, Jo...
# 360  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
#
#                                     Published PDF Language  \
# 0    Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 1    Submitted 11/14/2022 - Posted 11/29/2022          PDF
# 2    Submitted 11/11/2022 - Posted 11/11/2022          PDF
# 3    Submitted 11/10/2022 - Posted 11/16/2022          PDF
# 4    Submitted 11/07/2022 - Posted 11/07/2022          PDF
# ..                                        ...          ...
# 356  Submitted 04/13/2020 - Posted 04/13/2020          PDF
# 357  Submitted 04/11/2020 - Posted 04/28/2020          PDF
# 358  Submitted 04/10/2020 - Posted 06/04/2020          PDF
# 359  Submitted 04/09/2020 - Posted 04/09/2020          PDF
# 360  Submitted 04/06/2020 - Posted 04/08/2020          PDF
#
#                                                PDF URL  Submitted     Posted  \
# 0    https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-23
# 1    https://preprints.scielo.org/index.php/scielo/... 2022-11-14 2022-11-29
# 2    https://preprints.scielo.org/index.php/scielo/... 2022-11-11 2022-11-11
# 3    https://preprints.scielo.org/index.php/scielo/... 2022-11-10 2022-11-16
# 4    https://preprints.scielo.org/index.php/scielo/... 2022-11-07 2022-11-07
# ..                                                 ...        ...        ...
# 356  https://preprints.scielo.org/index.php/scielo/... 2020-04-13 2020-04-13
# 357  https://preprints.scielo.org/index.php/scielo/... 2020-04-11 2020-04-28
# 358  https://preprints.scielo.org/index.php/scielo/... 2020-04-10 2020-06-04
# 359  https://preprints.scielo.org/index.php/scielo/... 2020-04-09 2020-04-09
# 360  https://preprints.scielo.org/index.php/scielo/... 2020-04-06 2020-04-08
#
#      Text ID                                               Text
# 0    t000000  Publication status: Preprint has been publishe...
# 1    t000001  Publication status: Not informed by the submit...
# 2    t000002  Publication status: Preprint has been publishe...
# 3    t000003  Publication status: Preprint has been publishe...
# 4    t000004  Publication status: Preprint has been submitte...
# ..       ...                                                ...
# 356  t000356  V\nRadiol Bras. 2020 Mar/Abr;53(2):V–VI\n0100-...
# 357  t000357  Status: Preprint has been published in a journ...
# 358  t000358  Publication status: Preprint has been publishe...
# 359  t000359   \n \n \nArtigo Original \n \nVALIDAÇÃO DE PRO...
# 360  t000360    1/6\nRevista da Sociedade Brasileira de Medi...
#
# [361 rows x 10 columns]

# %% [markdown]
# ## Dropping articles that actually are not in English

# %% [markdown]
# The articles were visually inspected and the following ones were selected to be discarded.

# %%
article_drop_list = [
    't000001',
    't000017',
    't000023',
    't000037',
    't000051',
    't000053',
    't000057',
    't000058',
    't000066',
    't000067',
    't000074',
    't000095',
    't000096',
    't000101',
    't000111',
    't000113',
    't000114',
    't000116',
    't000119',
    't000124',
    't000131',
    't000136',
    't000139',
    't000142',
    't000143',
    't000149',
    't000154',
    't000158',
    't000167',
    't000171',
    't000175',
    't000180',
    't000185',
    't000186',
    't000190',
    't000205',
    't000224',
    't000232',
    't000233',
    't000239',
    't000240',
    't000311',
    't000329',
    't000339',
    't000359'
]

# %%
# Creating a boolean mask for the rows whose column 'Text ID' are in the list of articles to be dropped
mask = df_scielo_preprint_preChatGPT_en['Text ID'].isin(article_drop_list)

# Confirming the number of rows that are going to be dropped
counts = mask.value_counts()

# Display the counts
counts
# Out:
# Text ID
# False    316
# True      45
# Name: count, dtype: int64

# %%
# Retaining the rows whose column 'Text ID' are not in the list of articles to be dropped
df_scielo_preprint_preChatGPT_en = df_scielo_preprint_preChatGPT_en[~mask]
df_scielo_preprint_preChatGPT_en = df_scielo_preprint_preChatGPT_en.reset_index(drop=True)

# %%
df_scielo_preprint_preChatGPT_en
# Out:
#                                                  Title  \
# 0    (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1    Assembling the perfect bacterial genome using ...
# 2    ON METHODOLOGY AND METHODS FOR ANALYSING CLASS...
# 3    MOBILIZING LINGUISTIC AND SEMIOTIC RESOURCES, ...
# 4    PORTUGUESE AO PÉ DO BERIMBAU: ON CAPOEIRA AS A...
# ..                                                 ...
# 311  Challenges in the fight against the COVID-19 p...
# 312  Information about the new coronavirus disease ...
# 313  ACE2 diversity in placental mammals reveals th...
# 314  Coronavirus 2: Analysis of Regularity of Compl...
# 315  COVID-19 in Brazil: advantages of a socialized...
#
#                                                    URL  \
# 0    https://preprints.scielo.org/index.php/scielo/...
# 1    https://preprints.scielo.org/index.php/scielo/...
# 2    https://preprints.scielo.org/index.php/scielo/...
# 3    https://preprints.scielo.org/index.php/scielo/...
# 4    https://preprints.scielo.org/index.php/scielo/...
# ..                                                 ...
# 311  https://preprints.scielo.org/index.php/scielo/...
# 312  https://preprints.scielo.org/index.php/scielo/...
# 313  https://preprints.scielo.org/index.php/scielo/...
# 314  https://preprints.scielo.org/index.php/scielo/...
# 315  https://preprints.scielo.org/index.php/scielo/...
#
#                                                Authors  \
# 0      Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 1        Ryan R. Wick, Louise M. Judd, Kathryn E. Holt
# 2                              Leonardo Goncalves Lago
# 3                 Estêvão Cabral, Marylin Martin-Jones
# 4                        Mike Baynham, Jolana Hanusova
# ..                                                 ...
# 311               Eduardo Alexandrino Servolo Medeiros
# 312            Claudio Márcio Amaral de Oliveira  Lima
# 313  Bibiana Sampaio de Oliveira Fam, Pedro Vargas-...
# 314                                 Yuri Morales-López
# 315  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
#
#                                     Published PDF Language  \
# 0    Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 1    Submitted 11/11/2022 - Posted 11/11/2022          PDF
# 2    Submitted 11/10/2022 - Posted 11/16/2022          PDF
# 3    Submitted 11/07/2022 - Posted 11/07/2022          PDF
# 4    Submitted 11/04/2022 - Posted 11/04/2022          PDF
# ..                                        ...          ...
# 311  Submitted 04/15/2020 - Posted 04/15/2020          PDF
# 312  Submitted 04/13/2020 - Posted 04/13/2020          PDF
# 313  Submitted 04/11/2020 - Posted 04/28/2020          PDF
# 314  Submitted 04/10/2020 - Posted 06/04/2020          PDF
# 315  Submitted 04/06/2020 - Posted 04/08/2020          PDF
#
#                                                PDF URL  Submitted     Posted  \
# 0    https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-23
# 1    https://preprints.scielo.org/index.php/scielo/... 2022-11-11 2022-11-11
# 2    https://preprints.scielo.org/index.php/scielo/... 2022-11-10 2022-11-16
# 3    https://preprints.scielo.org/index.php/scielo/... 2022-11-07 2022-11-07
# 4    https://preprints.scielo.org/index.php/scielo/... 2022-11-04 2022-11-04
# ..                                                 ...        ...        ...
# 311  https://preprints.scielo.org/index.php/scielo/... 2020-04-15 2020-04-15
# 312  https://preprints.scielo.org/index.php/scielo/... 2020-04-13 2020-04-13
# 313  https://preprints.scielo.org/index.php/scielo/... 2020-04-11 2020-04-28
# 314  https://preprints.scielo.org/index.php/scielo/... 2020-04-10 2020-06-04
# 315  https://preprints.scielo.org/index.php/scielo/... 2020-04-06 2020-04-08
#
#      Text ID                                               Text
# 0    t000000  Publication status: Preprint has been publishe...
# 1    t000002  Publication status: Preprint has been publishe...
# 2    t000003  Publication status: Preprint has been publishe...
# 3    t000004  Publication status: Preprint has been submitte...
# 4    t000005  Publication status: Preprint has been submitte...
# ..       ...                                                ...
# 311  t000355  *Corresponding author. E-mail: edubalaccih@gma...
# 312  t000356  V\nRadiol Bras. 2020 Mar/Abr;53(2):V–VI\n0100-...
# 313  t000357  Status: Preprint has been published in a journ...
# 314  t000358  Publication status: Preprint has been publishe...
# 315  t000360    1/6\nRevista da Sociedade Brasileira de Medi...
#
# [316 rows x 10 columns]

# %%
# Redefining the column 'Text ID'
df_scielo_preprint_preChatGPT_en = df_scielo_preprint_preChatGPT_en.drop(columns=['Text ID']) # Dropping the previous one
df_scielo_preprint_preChatGPT_en['Text ID'] = 't' + df_scielo_preprint_preChatGPT_en.index.astype(str).str.zfill(6) # Creating a new one

# %%
df_scielo_preprint_preChatGPT_en
# Out:
#                                                  Title  \
# 0    (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1    Assembling the perfect bacterial genome using ...
# 2    ON METHODOLOGY AND METHODS FOR ANALYSING CLASS...
# 3    MOBILIZING LINGUISTIC AND SEMIOTIC RESOURCES, ...
# 4    PORTUGUESE AO PÉ DO BERIMBAU: ON CAPOEIRA AS A...
# ..                                                 ...
# 311  Challenges in the fight against the COVID-19 p...
# 312  Information about the new coronavirus disease ...
# 313  ACE2 diversity in placental mammals reveals th...
# 314  Coronavirus 2: Analysis of Regularity of Compl...
# 315  COVID-19 in Brazil: advantages of a socialized...
#
#                                                    URL  \
# 0    https://preprints.scielo.org/index.php/scielo/...
# 1    https://preprints.scielo.org/index.php/scielo/...
# 2    https://preprints.scielo.org/index.php/scielo/...
# 3    https://preprints.scielo.org/index.php/scielo/...
# 4    https://preprints.scielo.org/index.php/scielo/...
# ..                                                 ...
# 311  https://preprints.scielo.org/index.php/scielo/...
# 312  https://preprints.scielo.org/index.php/scielo/...
# 313  https://preprints.scielo.org/index.php/scielo/...
# 314  https://preprints.scielo.org/index.php/scielo/...
# 315  https://preprints.scielo.org/index.php/scielo/...
#
#                                                Authors  \
# 0      Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 1        Ryan R. Wick, Louise M. Judd, Kathryn E. Holt
# 2                              Leonardo Goncalves Lago
# 3                 Estêvão Cabral, Marylin Martin-Jones
# 4                        Mike Baynham, Jolana Hanusova
# ..                                                 ...
# 311               Eduardo Alexandrino Servolo Medeiros
# 312            Claudio Márcio Amaral de Oliveira  Lima
# 313  Bibiana Sampaio de Oliveira Fam, Pedro Vargas-...
# 314                                 Yuri Morales-López
# 315  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
#
#                                     Published PDF Language  \
# 0    Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 1    Submitted 11/11/2022 - Posted 11/11/2022          PDF
# 2    Submitted 11/10/2022 - Posted 11/16/2022          PDF
# 3    Submitted 11/07/2022 - Posted 11/07/2022          PDF
# 4    Submitted 11/04/2022 - Posted 11/04/2022          PDF
# ..                                        ...          ...
# 311  Submitted 04/15/2020 - Posted 04/15/2020          PDF
# 312  Submitted 04/13/2020 - Posted 04/13/2020          PDF
# 313  Submitted 04/11/2020 - Posted 04/28/2020          PDF
# 314  Submitted 04/10/2020 - Posted 06/04/2020          PDF
# 315  Submitted 04/06/2020 - Posted 04/08/2020          PDF
#
#                                                PDF URL  Submitted     Posted  \
# 0    https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-23
# 1    https://preprints.scielo.org/index.php/scielo/... 2022-11-11 2022-11-11
# 2    https://preprints.scielo.org/index.php/scielo/... 2022-11-10 2022-11-16
# 3    https://preprints.scielo.org/index.php/scielo/... 2022-11-07 2022-11-07
# 4    https://preprints.scielo.org/index.php/scielo/... 2022-11-04 2022-11-04
# ..                                                 ...        ...        ...
# 311  https://preprints.scielo.org/index.php/scielo/... 2020-04-15 2020-04-15
# 312  https://preprints.scielo.org/index.php/scielo/... 2020-04-13 2020-04-13
# 313  https://preprints.scielo.org/index.php/scielo/... 2020-04-11 2020-04-28
# 314  https://preprints.scielo.org/index.php/scielo/... 2020-04-10 2020-06-04
# 315  https://preprints.scielo.org/index.php/scielo/... 2020-04-06 2020-04-08
#
#                                                   Text  Text ID
# 0    Publication status: Preprint has been publishe...  t000000
# 1    Publication status: Preprint has been publishe...  t000001
# 2    Publication status: Preprint has been publishe...  t000002
# 3    Publication status: Preprint has been submitte...  t000003
# 4    Publication status: Preprint has been submitte...  t000004
# ..                                                 ...      ...
# 311  *Corresponding author. E-mail: edubalaccih@gma...  t000311
# 312  V\nRadiol Bras. 2020 Mar/Abr;53(2):V–VI\n0100-...  t000312
# 313  Status: Preprint has been published in a journ...  t000313
# 314  Publication status: Preprint has been publishe...  t000314
# 315    1/6\nRevista da Sociedade Brasileira de Medi...  t000315
#
# [316 rows x 10 columns]

# %% [markdown]
# ## Exporting to a file

# %%
df_scielo_preprint_preChatGPT_en.to_json(f"{output_directory}/scielo_erpp_pp.jsonl", orient='records', lines=True)
