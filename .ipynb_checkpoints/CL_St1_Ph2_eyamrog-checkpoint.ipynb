# %% [markdown]
# <center>
# <img src="https://laelgelcpublic.s3.sa-east-1.amazonaws.com/lael_50_years_narrow_white.png.no_years.400px_96dpi.png" width="300" alt="LAEL 50 years logo">
# <h3>APPLIED LINGUISTICS GRADUATE PROGRAMME (LAEL)</h3>
# </center>
# <hr>

# %% [markdown]
# # Corpus Linguistics - Study 1 - Phase 2 - eyamrog

# %% [markdown]
# The aim of this phase is to web scrape the archive of preprints of [SciELO](https://scielo.org/) (Scientific Electronic Library Online).
#
# - [SciELO Preprints](https://preprints.scielo.org/index.php/scielo)

# %% [markdown]
# ## Required Python packages

# %% [markdown]
# - beautifulsoup4
# - lxml
# - pandas
# - requests

# %% [markdown]
# ## Importing the required libraries

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import os
import sys

# %% [markdown]
# ## Defining input variables

# %%
output_directory = 'cl_st1_ph2_eyamrog'

# %% [markdown]
# ## Creating output directory

# %%
# Check if the output directory already exists. If it does, do nothing. If it doesn't exist, create it.
if os.path.exists(output_directory):
    print('Output directory already exists.')
else:
    try:
        os.makedirs(output_directory)
        print('Output directory successfully created.')
    except OSError as e:
        print('Failed to create the directory:', e)
        sys.exit(1)
# Out:
# Output directory already exists.

# %% [markdown]
# ## Scraping `SciELO Preprints` archive

# %% [markdown]
# In 17/09/2024, `SciELO Preprints` archive was described in 173 web pages.

# %%
start_page = 1
end_page = 173

# %%
# Initialising an empty list to store the data
data = []

# Iterating through the URLs
for i in range(start_page, end_page + 1):
    url = f'https://preprints.scielo.org/index.php/scielo/preprints/index/{i}'
    response = requests.get(url, verify=False) # SciELO's SSL certificate could not be verified ('SSLError: CERTIFICATE_VERIFY_FAILED'), so SSL verification had to be disabled
    soup = BeautifulSoup(response.content, 'lxml')
    
    # Find all <div> elements with the class 'obj_article_summary'
    articles = soup.find_all('div', class_='obj_article_summary')
    
    for article in articles:
        # Extract the title
        title_tag = article.find('div', class_='title').find('a')
        title = title_tag.get_text(strip=True)
        title_url = title_tag.get('href')
        
        # Extract the authors
        authors = article.find('div', class_='authors').get_text(strip=True)
        
        # Extract the published date
        published = article.find('div', class_='published').get_text(strip=True)
        
        # Extract the PDF link
        pdf_link_tag = article.find('a', class_='obj_galley_link pdf')
        pdf_link = pdf_link_tag.get('href') if pdf_link_tag else 'No PDF link'
        pdf_text = pdf_link_tag.get_text(strip=True) if pdf_link_tag else 'No PDF text'
        
        # Append the data to the list
        data.append({
            'Title': title,
            'URL': title_url,
            'Authors': authors,
            'Published': published,
            'PDF Language': pdf_text,
            'PDF URL': pdf_link
        })

# Create a pandas DataFrame from the data
df_scielo_preprint = pd.DataFrame(data)

# %%
df_scielo_preprint
# Out:
#                                                   Title  \
# 0     The sun rises for everyone: popular entreprene...
# 1     FROM TEXT TO FABRIC: RESONANCES OF GILBERTO FR...
# 2     Perception of formative and summative assessme...
# 3     SCIENTIFIC AND TECHNOLOGICAL LITERACY: CONTRIB...
# 4     COGNITIVE AND METACOGNITIVE STRATEGIES IN DIGI...
# ...                                                 ...
# 3452                      SARS-CoV-2: a clinical update
# 3453  MULTIPROFESSIONAL ELECTRONIC PROTOCOL FOR DIGE...
# 3454  Overview of confirmed cases of COVID-19 in fiv...
# 3455  COVID-19 in the State of Ceará: behaviors and ...
# 3456  COVID-19 in Brazil: advantages of a socialized...
#
#                                                     URL  \
# 0     https://preprints.scielo.org/index.php/scielo/...
# 1     https://preprints.scielo.org/index.php/scielo/...
# 2     https://preprints.scielo.org/index.php/scielo/...
# 3     https://preprints.scielo.org/index.php/scielo/...
# 4     https://preprints.scielo.org/index.php/scielo/...
# ...                                                 ...
# 3452  https://preprints.scielo.org/index.php/scielo/...
# 3453  https://preprints.scielo.org/index.php/scielo/...
# 3454  https://preprints.scielo.org/index.php/scielo/...
# 3455  https://preprints.scielo.org/index.php/scielo/...
# 3456  https://preprints.scielo.org/index.php/scielo/...
#
#                                                 Authors  \
# 0                                        Henrique Costa
# 1                      Rodrigo Medeiros, Lucas Oliveira
# 2     Martha Quiroz Figueroa, Mercedes María Lucas C...
# 3     Débora Danieli Pontarollo Gonçalves, Marizete ...
# 4     Fernando Silvio Cavalcante Pimentel, Daniela K...
# ...                                                 ...
# 3452     Mateus da Silveira Cespedes, José Carlos Souza
# 3453  Osvaldo Malafaia, Faruk Abrão  KALIL-FILHO, Jo...
# 3454                 NILA ALBUQUERQUE, Nathália Pedrosa
# 3455  Danilo Lima, Aldo Dias, Renata Rabelo, Igor Cr...
# 3456  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
#
#                                      Published              PDF Language  \
# 0     Submitted 09/16/2024 - Posted 09/17/2024  PDF (Português (Brasil))
# 1     Submitted 09/13/2024 - Posted 09/17/2024  PDF (Português (Brasil))
# 2     Submitted 09/13/2024 - Posted 09/17/2024    PDF (Español (España))
# 3     Submitted 09/16/2024 - Posted 09/17/2024  PDF (Português (Brasil))
# 4     Submitted 09/14/2024 - Posted 09/17/2024                       PDF
# ...                                        ...                       ...
# 3452  Submitted 04/10/2020 - Posted 04/13/2020  PDF (Português (Brasil))
# 3453  Submitted 04/09/2020 - Posted 04/09/2020                       PDF
# 3454  Submitted 04/09/2020 - Posted 04/09/2020  PDF (Português (Brasil))
# 3455  Submitted 04/08/2020 - Posted 04/09/2020  PDF (Português (Brasil))
# 3456  Submitted 04/06/2020 - Posted 04/08/2020                       PDF
#
#                                                 PDF URL
# 0     https://preprints.scielo.org/index.php/scielo/...
# 1     https://preprints.scielo.org/index.php/scielo/...
# 2     https://preprints.scielo.org/index.php/scielo/...
# 3     https://preprints.scielo.org/index.php/scielo/...
# 4     https://preprints.scielo.org/index.php/scielo/...
# ...                                                 ...
# 3452  https://preprints.scielo.org/index.php/scielo/...
# 3453  https://preprints.scielo.org/index.php/scielo/...
# 3454  https://preprints.scielo.org/index.php/scielo/...
# 3455  https://preprints.scielo.org/index.php/scielo/...
# 3456  https://preprints.scielo.org/index.php/scielo/...
#
# [3457 rows x 6 columns]

# %% [markdown]
# ### Removing duplicates

# %%
df_scielo_preprint.drop_duplicates(subset='URL', keep='first', inplace=True)
df_scielo_preprint = df_scielo_preprint.reset_index(drop=True)
df_scielo_preprint.shape
# Out:
# (3297, 6)

# %% [markdown]
# ### Initialising the columns `Submitted` and `Posted`

# %%
df_scielo_preprint.at[0, 'Submitted'] = '12/31/2024'
df_scielo_preprint.at[0, 'Posted'] = '12/31/2024'

# %% [markdown]
# ### Extracting the `Submitted` and `Posted` dates from the column `Published`

# %%
# Defining a function to extract dates using RegEx
def extract_dates(published):
    match = re.search(r'Submitted (\d{2}/\d{2}/\d{4}) - Posted (\d{2}/\d{2}/\d{4})', published)
    if match:
        return match.group(1), match.group(2)
    return None, None

# Applying the function to the 'Published' column and create new columns
df_scielo_preprint['Submitted'], df_scielo_preprint['Posted'] = zip(*df_scielo_preprint['Published'].apply(extract_dates))

# %%
df_scielo_preprint['Submitted'] = pd.to_datetime(df_scielo_preprint['Submitted'])
df_scielo_preprint['Posted'] = pd.to_datetime(df_scielo_preprint['Posted'])

# %%
df_scielo_preprint.dtypes
# Out:
# Title                   object
# URL                     object
# Authors                 object
# Published               object
# PDF Language            object
# PDF URL                 object
# Submitted       datetime64[ns]
# Posted          datetime64[ns]
# dtype: object

# %%
df_scielo_preprint
# Out:
#                                                   Title  \
# 0     The sun rises for everyone: popular entreprene...
# 1     FROM TEXT TO FABRIC: RESONANCES OF GILBERTO FR...
# 2     Perception of formative and summative assessme...
# 3     SCIENTIFIC AND TECHNOLOGICAL LITERACY: CONTRIB...
# 4     COGNITIVE AND METACOGNITIVE STRATEGIES IN DIGI...
# ...                                                 ...
# 3292                      SARS-CoV-2: a clinical update
# 3293  MULTIPROFESSIONAL ELECTRONIC PROTOCOL FOR DIGE...
# 3294  Overview of confirmed cases of COVID-19 in fiv...
# 3295  COVID-19 in the State of Ceará: behaviors and ...
# 3296  COVID-19 in Brazil: advantages of a socialized...
#
#                                                     URL  \
# 0     https://preprints.scielo.org/index.php/scielo/...
# 1     https://preprints.scielo.org/index.php/scielo/...
# 2     https://preprints.scielo.org/index.php/scielo/...
# 3     https://preprints.scielo.org/index.php/scielo/...
# 4     https://preprints.scielo.org/index.php/scielo/...
# ...                                                 ...
# 3292  https://preprints.scielo.org/index.php/scielo/...
# 3293  https://preprints.scielo.org/index.php/scielo/...
# 3294  https://preprints.scielo.org/index.php/scielo/...
# 3295  https://preprints.scielo.org/index.php/scielo/...
# 3296  https://preprints.scielo.org/index.php/scielo/...
#
#                                                 Authors  \
# 0                                        Henrique Costa
# 1                      Rodrigo Medeiros, Lucas Oliveira
# 2     Martha Quiroz Figueroa, Mercedes María Lucas C...
# 3     Débora Danieli Pontarollo Gonçalves, Marizete ...
# 4     Fernando Silvio Cavalcante Pimentel, Daniela K...
# ...                                                 ...
# 3292     Mateus da Silveira Cespedes, José Carlos Souza
# 3293  Osvaldo Malafaia, Faruk Abrão  KALIL-FILHO, Jo...
# 3294                 NILA ALBUQUERQUE, Nathália Pedrosa
# 3295  Danilo Lima, Aldo Dias, Renata Rabelo, Igor Cr...
# 3296  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
#
#                                      Published              PDF Language  \
# 0     Submitted 09/16/2024 - Posted 09/17/2024  PDF (Português (Brasil))
# 1     Submitted 09/13/2024 - Posted 09/17/2024  PDF (Português (Brasil))
# 2     Submitted 09/13/2024 - Posted 09/17/2024    PDF (Español (España))
# 3     Submitted 09/16/2024 - Posted 09/17/2024  PDF (Português (Brasil))
# 4     Submitted 09/14/2024 - Posted 09/17/2024                       PDF
# ...                                        ...                       ...
# 3292  Submitted 04/10/2020 - Posted 04/13/2020  PDF (Português (Brasil))
# 3293  Submitted 04/09/2020 - Posted 04/09/2020                       PDF
# 3294  Submitted 04/09/2020 - Posted 04/09/2020  PDF (Português (Brasil))
# 3295  Submitted 04/08/2020 - Posted 04/09/2020  PDF (Português (Brasil))
# 3296  Submitted 04/06/2020 - Posted 04/08/2020                       PDF
#
#                                                 PDF URL  Submitted     Posted
# 0     https://preprints.scielo.org/index.php/scielo/... 2024-09-16 2024-09-17
# 1     https://preprints.scielo.org/index.php/scielo/... 2024-09-13 2024-09-17
# 2     https://preprints.scielo.org/index.php/scielo/... 2024-09-13 2024-09-17
# 3     https://preprints.scielo.org/index.php/scielo/... 2024-09-16 2024-09-17
# 4     https://preprints.scielo.org/index.php/scielo/... 2024-09-14 2024-09-17
# ...                                                 ...        ...        ...
# 3292  https://preprints.scielo.org/index.php/scielo/... 2020-04-10 2020-04-13
# 3293  https://preprints.scielo.org/index.php/scielo/... 2020-04-09 2020-04-09
# 3294  https://preprints.scielo.org/index.php/scielo/... 2020-04-09 2020-04-09
# 3295  https://preprints.scielo.org/index.php/scielo/... 2020-04-08 2020-04-09
# 3296  https://preprints.scielo.org/index.php/scielo/... 2020-04-06 2020-04-08
#
# [3297 rows x 8 columns]

# %% [markdown]
# ### Sorting the DataFrame by the column `Submitted` in descending order

# %%
df_scielo_preprint = df_scielo_preprint.sort_values(by='Submitted', ascending=False)
df_scielo_preprint = df_scielo_preprint.reset_index(drop=True)

# %%
df_scielo_preprint
# Out:
#                                                   Title  \
# 0     The sun rises for everyone: popular entreprene...
# 1     Risk of Adverse Health Outcomes in Patients wi...
# 2     SCIENTIFIC AND TECHNOLOGICAL LITERACY: CONTRIB...
# 3     COGNITIVE AND METACOGNITIVE STRATEGIES IN DIGI...
# 4     PUBLIC POLICIES AND EVANGELICAL WOMEN IN POLITICS
# ...                                                 ...
# 3292  Overview of confirmed cases of COVID-19 in fiv...
# 3293  Education before the advance of COVID-19 in Pa...
# 3294  MULTIPROFESSIONAL ELECTRONIC PROTOCOL FOR DIGE...
# 3295  COVID-19 in the State of Ceará: behaviors and ...
# 3296  COVID-19 in Brazil: advantages of a socialized...
#
#                                                     URL  \
# 0     https://preprints.scielo.org/index.php/scielo/...
# 1     https://preprints.scielo.org/index.php/scielo/...
# 2     https://preprints.scielo.org/index.php/scielo/...
# 3     https://preprints.scielo.org/index.php/scielo/...
# 4     https://preprints.scielo.org/index.php/scielo/...
# ...                                                 ...
# 3292  https://preprints.scielo.org/index.php/scielo/...
# 3293  https://preprints.scielo.org/index.php/scielo/...
# 3294  https://preprints.scielo.org/index.php/scielo/...
# 3295  https://preprints.scielo.org/index.php/scielo/...
# 3296  https://preprints.scielo.org/index.php/scielo/...
#
#                                                 Authors  \
# 0                                        Henrique Costa
# 1     Marcus Vinícius Bolívar Malachias, Sergio Eman...
# 2     Débora Danieli Pontarollo Gonçalves, Marizete ...
# 3     Fernando Silvio Cavalcante Pimentel, Daniela K...
# 4                                       Jamille Bezerra
# ...                                                 ...
# 3292                 NILA ALBUQUERQUE, Nathália Pedrosa
# 3293                                       Mirta Britez
# 3294  Osvaldo Malafaia, Faruk Abrão  KALIL-FILHO, Jo...
# 3295  Danilo Lima, Aldo Dias, Renata Rabelo, Igor Cr...
# 3296  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
#
#                                      Published              PDF Language  \
# 0     Submitted 09/16/2024 - Posted 09/17/2024  PDF (Português (Brasil))
# 1     Submitted 09/16/2024 - Posted 09/16/2024                       PDF
# 2     Submitted 09/16/2024 - Posted 09/17/2024  PDF (Português (Brasil))
# 3     Submitted 09/14/2024 - Posted 09/17/2024                       PDF
# 4     Submitted 09/13/2024 - Posted 09/14/2024  PDF (Português (Brasil))
# ...                                        ...                       ...
# 3292  Submitted 04/09/2020 - Posted 04/09/2020  PDF (Português (Brasil))
# 3293  Submitted 04/09/2020 - Posted 05/13/2020    PDF (Español (España))
# 3294  Submitted 04/09/2020 - Posted 04/09/2020                       PDF
# 3295  Submitted 04/08/2020 - Posted 04/09/2020  PDF (Português (Brasil))
# 3296  Submitted 04/06/2020 - Posted 04/08/2020                       PDF
#
#                                                 PDF URL  Submitted     Posted
# 0     https://preprints.scielo.org/index.php/scielo/... 2024-09-16 2024-09-17
# 1     https://preprints.scielo.org/index.php/scielo/... 2024-09-16 2024-09-16
# 2     https://preprints.scielo.org/index.php/scielo/... 2024-09-16 2024-09-17
# 3     https://preprints.scielo.org/index.php/scielo/... 2024-09-14 2024-09-17
# 4     https://preprints.scielo.org/index.php/scielo/... 2024-09-13 2024-09-14
# ...                                                 ...        ...        ...
# 3292  https://preprints.scielo.org/index.php/scielo/... 2020-04-09 2020-04-09
# 3293  https://preprints.scielo.org/index.php/scielo/... 2020-04-09 2020-05-13
# 3294  https://preprints.scielo.org/index.php/scielo/... 2020-04-09 2020-04-09
# 3295  https://preprints.scielo.org/index.php/scielo/... 2020-04-08 2020-04-09
# 3296  https://preprints.scielo.org/index.php/scielo/... 2020-04-06 2020-04-08
#
# [3297 rows x 8 columns]

# %% [markdown]
# ### Exporting to a file

# %%
df_scielo_preprint.to_json(f'{output_directory}/scielo_preprint_archive.jsonl', orient='records', lines=True)

# %% [markdown]
# ## Selecting articles submitted before the advent of ChatGPT

# %% [markdown]
# ChatGPT was released by OpenAI on November 30, 2022.

# %%
df_scielo_preprint_preChatGPT = df_scielo_preprint[df_scielo_preprint['Submitted'] <= '2022-11-30']
df_scielo_preprint_preChatGPT = df_scielo_preprint_preChatGPT.reset_index(drop=True)

# %%
df_scielo_preprint_preChatGPT
# Out:
#                                                   Title  \
# 0     DIALOGUES BETWEEN EDUCATION, ART AND CULTURAL ...
# 1     Leadership for the Implementation of the Organ...
# 2     Social network analysis as a methodology for r...
# 3     Standardized Learning Assessment in higher edu...
# 4     State of the art on the Social Network Analysi...
# ...                                                 ...
# 1971  Overview of confirmed cases of COVID-19 in fiv...
# 1972  Education before the advance of COVID-19 in Pa...
# 1973  MULTIPROFESSIONAL ELECTRONIC PROTOCOL FOR DIGE...
# 1974  COVID-19 in the State of Ceará: behaviors and ...
# 1975  COVID-19 in Brazil: advantages of a socialized...
#
#                                                     URL  \
# 0     https://preprints.scielo.org/index.php/scielo/...
# 1     https://preprints.scielo.org/index.php/scielo/...
# 2     https://preprints.scielo.org/index.php/scielo/...
# 3     https://preprints.scielo.org/index.php/scielo/...
# 4     https://preprints.scielo.org/index.php/scielo/...
# ...                                                 ...
# 1971  https://preprints.scielo.org/index.php/scielo/...
# 1972  https://preprints.scielo.org/index.php/scielo/...
# 1973  https://preprints.scielo.org/index.php/scielo/...
# 1974  https://preprints.scielo.org/index.php/scielo/...
# 1975  https://preprints.scielo.org/index.php/scielo/...
#
#                                                 Authors  \
# 0                  Bruno Nogueira, Daniela Nery Bracchi
# 1     Verónica Ramírez-Sánchez, Maria del Carmen San...
# 2                                Rebecca Vargas-Bolaños
# 3               Jorge Gutierrez, Luis Alan Acuña Gamboa
# 4                                Rebecca Vargas-Bolaños
# ...                                                 ...
# 1971                 NILA ALBUQUERQUE, Nathália Pedrosa
# 1972                                       Mirta Britez
# 1973  Osvaldo Malafaia, Faruk Abrão  KALIL-FILHO, Jo...
# 1974  Danilo Lima, Aldo Dias, Renata Rabelo, Igor Cr...
# 1975  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
#
#                                      Published              PDF Language  \
# 0     Submitted 11/27/2022 - Posted 12/02/2022  PDF (Português (Brasil))
# 1     Submitted 11/27/2022 - Posted 12/01/2022    PDF (Español (España))
# 2     Submitted 11/23/2022 - Posted 12/01/2022    PDF (Español (España))
# 3     Submitted 11/22/2022 - Posted 11/25/2022    PDF (Español (España))
# 4     Submitted 11/22/2022 - Posted 12/01/2022    PDF (Español (España))
# ...                                        ...                       ...
# 1971  Submitted 04/09/2020 - Posted 04/09/2020  PDF (Português (Brasil))
# 1972  Submitted 04/09/2020 - Posted 05/13/2020    PDF (Español (España))
# 1973  Submitted 04/09/2020 - Posted 04/09/2020                       PDF
# 1974  Submitted 04/08/2020 - Posted 04/09/2020  PDF (Português (Brasil))
# 1975  Submitted 04/06/2020 - Posted 04/08/2020                       PDF
#
#                                                 PDF URL  Submitted     Posted
# 0     https://preprints.scielo.org/index.php/scielo/... 2022-11-27 2022-12-02
# 1     https://preprints.scielo.org/index.php/scielo/... 2022-11-27 2022-12-01
# 2     https://preprints.scielo.org/index.php/scielo/... 2022-11-23 2022-12-01
# 3     https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-25
# 4     https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-12-01
# ...                                                 ...        ...        ...
# 1971  https://preprints.scielo.org/index.php/scielo/... 2020-04-09 2020-04-09
# 1972  https://preprints.scielo.org/index.php/scielo/... 2020-04-09 2020-05-13
# 1973  https://preprints.scielo.org/index.php/scielo/... 2020-04-09 2020-04-09
# 1974  https://preprints.scielo.org/index.php/scielo/... 2020-04-08 2020-04-09
# 1975  https://preprints.scielo.org/index.php/scielo/... 2020-04-06 2020-04-08
#
# [1976 rows x 8 columns]

# %% [markdown]
# ## Selecting the articles in English

# %% [markdown]
# Articles written in English are usually the ones whose button is `PDF`.

# %%
df_scielo_preprint_preChatGPT_en = df_scielo_preprint_preChatGPT[df_scielo_preprint_preChatGPT['PDF Language'] == 'PDF']
df_scielo_preprint_preChatGPT_en = df_scielo_preprint_preChatGPT_en.reset_index(drop=True)

# %%
df_scielo_preprint_preChatGPT_en
# Out:
#                                                  Title  \
# 0    (Fern flora of Viçosa, Minas Gerais State, Bra...
# 1    Belching as a symptom of COVID-19: Case presen...
# 2    Assembling the perfect bacterial genome using ...
# 3    ON METHODOLOGY AND METHODS FOR ANALYSING CLASS...
# 4    MOBILIZING LINGUISTIC AND SEMIOTIC RESOURCES, ...
# ..                                                 ...
# 343  Information about the new coronavirus disease ...
# 344  ACE2 diversity in placental mammals reveals th...
# 345  Coronavirus 2: Analysis of Regularity of Compl...
# 346  MULTIPROFESSIONAL ELECTRONIC PROTOCOL FOR DIGE...
# 347  COVID-19 in Brazil: advantages of a socialized...
#
#                                                    URL  \
# 0    https://preprints.scielo.org/index.php/scielo/...
# 1    https://preprints.scielo.org/index.php/scielo/...
# 2    https://preprints.scielo.org/index.php/scielo/...
# 3    https://preprints.scielo.org/index.php/scielo/...
# 4    https://preprints.scielo.org/index.php/scielo/...
# ..                                                 ...
# 343  https://preprints.scielo.org/index.php/scielo/...
# 344  https://preprints.scielo.org/index.php/scielo/...
# 345  https://preprints.scielo.org/index.php/scielo/...
# 346  https://preprints.scielo.org/index.php/scielo/...
# 347  https://preprints.scielo.org/index.php/scielo/...
#
#                                                Authors  \
# 0      Nelson Túlio Lage Pena, Pedro Bond Schwartsburd
# 1    Nuvia Novoa Acosta, Liuba Yamila Peña Galbán, ...
# 2        Ryan R. Wick, Louise M. Judd, Kathryn E. Holt
# 3                              Leonardo Goncalves Lago
# 4                 Estêvão Cabral, Marylin Martin-Jones
# ..                                                 ...
# 343            Claudio Márcio Amaral de Oliveira  Lima
# 344  Bibiana Sampaio de Oliveira Fam, Pedro Vargas-...
# 345                                 Yuri Morales-López
# 346  Osvaldo Malafaia, Faruk Abrão  KALIL-FILHO, Jo...
# 347  Julio Croda, Wanderson Kleber de  Oliveira, Ro...
#
#                                     Published PDF Language  \
# 0    Submitted 11/22/2022 - Posted 11/23/2022          PDF
# 1    Submitted 11/14/2022 - Posted 11/29/2022          PDF
# 2    Submitted 11/11/2022 - Posted 11/11/2022          PDF
# 3    Submitted 11/10/2022 - Posted 11/16/2022          PDF
# 4    Submitted 11/07/2022 - Posted 11/07/2022          PDF
# ..                                        ...          ...
# 343  Submitted 04/13/2020 - Posted 04/13/2020          PDF
# 344  Submitted 04/11/2020 - Posted 04/28/2020          PDF
# 345  Submitted 04/10/2020 - Posted 06/04/2020          PDF
# 346  Submitted 04/09/2020 - Posted 04/09/2020          PDF
# 347  Submitted 04/06/2020 - Posted 04/08/2020          PDF
#
#                                                PDF URL  Submitted     Posted
# 0    https://preprints.scielo.org/index.php/scielo/... 2022-11-22 2022-11-23
# 1    https://preprints.scielo.org/index.php/scielo/... 2022-11-14 2022-11-29
# 2    https://preprints.scielo.org/index.php/scielo/... 2022-11-11 2022-11-11
# 3    https://preprints.scielo.org/index.php/scielo/... 2022-11-10 2022-11-16
# 4    https://preprints.scielo.org/index.php/scielo/... 2022-11-07 2022-11-07
# ..                                                 ...        ...        ...
# 343  https://preprints.scielo.org/index.php/scielo/... 2020-04-13 2020-04-13
# 344  https://preprints.scielo.org/index.php/scielo/... 2020-04-11 2020-04-28
# 345  https://preprints.scielo.org/index.php/scielo/... 2020-04-10 2020-06-04
# 346  https://preprints.scielo.org/index.php/scielo/... 2020-04-09 2020-04-09
# 347  https://preprints.scielo.org/index.php/scielo/... 2020-04-06 2020-04-08
#
# [348 rows x 8 columns]

# %% [markdown]
# ### Exporting to a file

# %%
df_scielo_preprint_preChatGPT_en.to_json(f'{output_directory}/scielo_preprint_preChatGPT_en.jsonl', orient='records', lines=True)
